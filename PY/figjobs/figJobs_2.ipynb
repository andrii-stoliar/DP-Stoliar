# %%
import os
import sys
import importlib

print("CWD:", os.getcwd())
print("sys.path[0]:", sys.path[0])
# Out:
# CWD: c:\MyFiles\Study\DP-Stoliar\PY_test\figjobs
# sys.path[0]: c:\Users\andre\anaconda3\python313.zip

# %%
import os
import importlib
import pandas as pd
import myfiglib

importlib.reload(myfiglib)
StackedFigure = myfiglib.StackedFigure

figSaveDir = "../fig"
os.makedirs(figSaveDir, exist_ok=True)
figName = "ts_prevodova_spirala"

data = pd.read_csv("../dataRepo/ts_prevodova3.csv", header=None).values

t = data[:, 0]
y = data[:, 2]

fig = StackedFigure(6, 1)

fig.panel(0, "čas [s]", "Špirála [V]")
fig.line(0, t, y, lw=0.5, color="k")

fig.save(os.path.join(figSaveDir, f"{figName}.png"))

# %%
import os
import importlib
import pandas as pd
import myfiglib

importlib.reload(myfiglib)
StackedFigure = myfiglib.StackedFigure

figSaveDir = "../fig"
os.makedirs(figSaveDir, exist_ok=True)
figName = "ts_prevodova_sensors3"

data = pd.read_csv("../dataRepo/ts_prevodova3.csv", header=None).values

t = data[:, 0]
y1 = data[:, 3]
y2 = data[:, 4]

fig = StackedFigure(7.2, 2, [1, 1])

fig.panel(0, "čas [s]", "Snímač 1 [V]", ylim=(3, 10))
fig.line(0, t, y1, lw=0.5, color="k")

fig.panel(1, "čas [s]", "Snímač 2 [V]", ylim=(3, 10))
fig.line(1, t, y2, lw=0.5, color="k")

fig.save(os.path.join(figSaveDir, f"{figName}.png"))

# %%
import os
import importlib
import pandas as pd
import myfiglib

importlib.reload(myfiglib)
StackedFigure = myfiglib.StackedFigure

figSaveDir = "../fig"
os.makedirs(figSaveDir, exist_ok=True)
figName = "ts_prevodova_sensors6"

data = pd.read_csv("../dataRepo/ts_prevodova6.csv", header=None).values

t = data[:, 0]
y1 = data[:, 3]
y2 = data[:, 4]

fig = StackedFigure(7.2, 2, [1, 1])

fig.panel(0, "čas [s]", "Snímač 1 [V]", ylim=(3, 10))
fig.line(0, t, y1, lw=0.5, color="k")

fig.panel(1, "čas [s]", "Snímač 2 [V]", ylim=(3, 10))
fig.line(1, t, y2, lw=0.5, color="k")

fig.save(os.path.join(figSaveDir, f"{figName}.png"))

# %%
import os
import importlib
import pandas as pd
import myfiglib

importlib.reload(myfiglib)
StackedFigure = myfiglib.StackedFigure

figSaveDir = "../fig"
os.makedirs(figSaveDir, exist_ok=True)
figName = "ts_prevodova_sensors9"

data = pd.read_csv("../dataRepo/ts_prevodova9.csv", header=None).values

t = data[:, 0]
y1 = data[:, 3]
y2 = data[:, 4]

fig = StackedFigure(7.2, 2, [1, 1])

fig.panel(0, "čas [s]", "Snímač 1 [V]", ylim=(3, 10))
fig.line(0, t, y1, lw=0.5, color="k")

fig.panel(1, "čas [s]", "Snímač 2 [V]", ylim=(3, 10))
fig.line(1, t, y2, lw=0.5, color="k")

fig.save(os.path.join(figSaveDir, f"{figName}.png"))

# %%
import os
import importlib
import pandas as pd
import myfiglib

importlib.reload(myfiglib)
StackedFigure = myfiglib.StackedFigure

figSaveDir = "../fig"
os.makedirs(figSaveDir, exist_ok=True)
figName = "ts_static_sensors3"

data = pd.read_csv("../dataRepo/ts_static3.csv", header=None).values

t = data[:, 0]
y1 = data[:, 1]
y2 = data[:, 2]

fig = StackedFigure(6.5, 2, [1, 1])

fig.panel(0, "Vstup [V]", "Snímač 1 [V]", ylim=(3, 10))
fig.line(0, t, y1, ls="--", lw=0.3, color="k", marker="o", ms=2)

fig.panel(1, "Vstup [V]", "Snímač 2 [V]", ylim=(3, 10))
fig.line(1, t, y2, ls="--", lw=0.3, color="k", marker="o", ms=2)

fig.save(os.path.join(figSaveDir, f"{figName}.png"))

# %%
import os
import importlib
import pandas as pd
import myfiglib

importlib.reload(myfiglib)
StackedFigure = myfiglib.StackedFigure

figSaveDir = "../fig"
os.makedirs(figSaveDir, exist_ok=True)
figName = "ts_static_sensors6"

data = pd.read_csv("../dataRepo/ts_static6.csv", header=None).values

t = data[:, 0]
y1 = data[:, 1]
y2 = data[:, 2]

fig = StackedFigure(6.5, 2, [1, 1])

fig.panel(0, "Vstup [V]", "Snímač 1 [V]", ylim=(3, 10))
fig.line(0, t, y1, ls="--", lw=0.3, color="k", marker="o", ms=2)

fig.panel(1, "Vstup [V]", "Snímač 2 [V]", ylim=(3, 10))
fig.line(1, t, y2, ls="--", lw=0.3, color="k", marker="o", ms=2)

fig.save(os.path.join(figSaveDir, f"{figName}.png"))

# %%
import os
import importlib
import pandas as pd
import myfiglib

importlib.reload(myfiglib)
StackedFigure = myfiglib.StackedFigure

figSaveDir = "../fig"
os.makedirs(figSaveDir, exist_ok=True)
figName = "ts_static_sensors9"

data = pd.read_csv("../dataRepo/ts_static9.csv", header=None).values

t = data[:, 0]
y1 = data[:, 1]
y2 = data[:, 2]

fig = StackedFigure(6.5, 2, [1, 1])

fig.panel(0, "Vstup [V]", "Snímač 1 [V]", ylim=(3, 10))
fig.line(0, t, y1, ls="--", lw=0.3, color="k", marker="o", ms=2)

fig.panel(1, "Vstup [V]", "Snímač 2 [V]", ylim=(3, 10))
fig.line(1, t, y2, ls="--", lw=0.3, color="k", marker="o", ms=2)

fig.save(os.path.join(figSaveDir, f"{figName}.png"))

# %%
import os
import importlib
import pandas as pd
import myfiglib

importlib.reload(myfiglib)
StackedFigure = myfiglib.StackedFigure

figSaveDir = "../fig"
os.makedirs(figSaveDir, exist_ok=True)
figName = "ts_pb_vent6_spir4_ident_raw"

data = pd.read_csv("../dataRepo/ts_pb_vent6_spir4_raw.csv", header=None, skiprows=1).values

t = data[:, 0]
y1 = data[:, 1]
y2 = data[:, 2]

fig = StackedFigure(8, 2, [1, 1])

fig.panel(0, "čas [s]", "Špirála [V]", ylim=(3, 5))
fig.line(0, t, y1, lw=0.5, color="k")

fig.panel(1, "čas [s]", "Snímač 1 [V]", ylim=(6, 7.5))
fig.line(1, t, y2, lw=0.5, color="k")

fig.save(os.path.join(figSaveDir, f"{figName}.png"))

# %%
import os
import importlib
import pandas as pd
import myfiglib

importlib.reload(myfiglib)
StackedFigure = myfiglib.StackedFigure

figSaveDir = "../fig"
os.makedirs(figSaveDir, exist_ok=True)
figName = "ts_pb_vent6_spir4_ident_raw_normalized"

data = pd.read_csv("../dataRepo/ts_pb_vent6_spir4_raw.csv", header=None, skiprows=1).values

t = data[:, 0]
y1 = data[:, 3]
y2 = data[:, 4]

fig = StackedFigure(10, 2, [1, 1])

fig.panel(0, "čas [s]", "Špirála [V]", ylim=(-0.6, 0.6))
fig.line(0, t, y1, lw=0.5, color="k")

fig.panel(1, "čas [s]", "Snímač 1 [V]", ylim=(-0.7, 0.7))
fig.line(1, t, y2, lw=0.5, color="k")

fig.save(os.path.join(figSaveDir, f"{figName}.png"))

# %%
import os
import importlib
import pandas as pd
import myfiglib

importlib.reload(myfiglib)
StackedFigure = myfiglib.StackedFigure

figSaveDir = "../fig"
os.makedirs(figSaveDir, exist_ok=True)
figName = "ts_pb_vent6_spir4_ident_avg"

data = pd.read_csv("../dataRepo/ts_pb_vent6_spir4_avg.csv", header=None, skiprows=1).values

t = data[:, 0]
y1 = data[:, 1]
y2 = data[:, 2]

fig = StackedFigure(7, 2, [1, 1])

fig.panel(0, "čas [s]", "Špirála [V]", ylim=(-0.6, 0.6))
fig.line(0, t, y1, lw=0.5, color="k")

fig.panel(1, "čas [s]", "Snímač 1 [V]", ylim=(-0.7, 0.7))
fig.line(1, t, y2, lw=0.5, color="k")

fig.save(os.path.join(figSaveDir, f"{figName}.png"))

# %%
import os
import importlib
import pandas as pd
import myfiglib

importlib.reload(myfiglib)
StackedFigure = myfiglib.StackedFigure

figSaveDir = "../fig"
os.makedirs(figSaveDir, exist_ok=True)
figName = "ts_pb_vent6_spir4_ident_comparison"

data = pd.read_csv("../dataRepo/ts_pb_vent6_spir4_id.csv", header=None, skiprows=1).values

t = data[:, 0]
y_meas = data[:, 2]
y_ls = data[:, 3]
y_fmin = data[:, 4]

fig = StackedFigure(6, 1)

fig.panel(0, "čas [s]", "Snímač 1 [V]")
fig.line(0, t, y_meas, lw=0.6, color="k", label="meraná")
fig.line(0, t, y_ls, ls="--", lw=0.8, color="tab:blue",
         label="m. najm. štvorcov")
fig.line(0, t, y_fmin, ls="--", lw=0.8, color="tab:red",
         label="m. fminsearch")

fig.save(os.path.join(figSaveDir, f"{figName}.png"), dpi=600)

# %%
import os
import importlib
import pandas as pd
import myfiglib

importlib.reload(myfiglib)
StackedFigure = myfiglib.StackedFigure

figSaveDir = "../fig"
os.makedirs(figSaveDir, exist_ok=True)
figName = "ts_pb_vent6_spir4_ident_approximated_comparison"

data = pd.read_csv("../dataRepo/ts_pb_vent6_spir4_id_apprx.csv", header=None, skiprows=1).values

t = data[:, 0]
y_meas = data[:, 2]
y_ls = data[:, 3]
y_fmin = data[:, 4]

fig = StackedFigure(6, 1)

fig.panel(0, "čas [s]", "Snímač 1 [V]")
fig.line(0, t, y_meas, lw=0.6, color="k", label="meraná")
fig.line(0, t, y_ls, ls="--", lw=0.8, color="tab:blue",
         label="m. najm. štvorcov")
fig.line(0, t, y_fmin, ls="--", lw=0.8, color="tab:red",
         label="m. fminsearch")

fig.save(os.path.join(figSaveDir, f"{figName}.png"), dpi=600)
