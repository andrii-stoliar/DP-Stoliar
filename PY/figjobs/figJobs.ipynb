# %%
# Obr. 3

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_prevodova_spirala'

# load CSV
data_main = pd.read_csv(
    '../dataRepo/ts_prevodova3.csv', 
    header=None
).values  

# ===== Panel =====

figPlotParam = fcnDefaultFigSize(6, 0.17, 0.88, 0.12, 0.4, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])
subPlots = gridspec.GridSpec(1, 1)
ax0 = plt.subplot(subPlots[0])


ax0.plot(data_main[:, 0], data_main[:, 2],
         '-', lw=0.5, color='k',
         drawstyle='default'
         )

fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3], figPlotParam[4], figPlotParam[5])
fcn_setFigStyle_basicTimeSeries(fig, figPlotParam, ['čas [s]', 'Špirála [V]', ''])
ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')

# ax0.set_xlim(0, 255)
# ax0.set_ylim(0, 1023)

plt.savefig(os.path.join(figSaveDir, f"{figName}.png"))
plt.close()

# %%
# Obr. 4

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_prevodova_sensors3'

# load CSV
data_main = pd.read_csv('../dataRepo/ts_prevodova3.csv', header=None, skiprows=0).values
t  = data_main[:, 0]
y1 = data_main[:, 3]   
y2 = data_main[:, 4]   

# ===== Panel =====
figPlotParam = fcnDefaultFigSize(7.2, 0.17, 0.88, 0.12, 0.40, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])
subPlots = gridspec.GridSpec(2, 1, height_ratios=[1, 1])


fcn_setFigStyle_basicTimeSeries(fig, figPlotParam, ['Čas [s]', '', ''])

# --- Horný graf
ax0 = plt.subplot(subPlots[0])
ax0.plot(t, y1, '-', lw=0.5, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax0)
ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax0.set_xlabel('čas [s]', ha='left', va='top')
ax0.xaxis.set_label_coords(1.05, -0.07, transform=ax0.transAxes)
ax0.set_ylabel('Snímač 1 [V]', ha='right', va='bottom', rotation=90)
ax0.yaxis.set_label_coords(-0.07, 1.05, transform=ax0.transAxes)
ax0.set_ylim(3, 10)

# --- Dolný graf
ax1 = plt.subplot(subPlots[1])
ax1.plot(t, y2, '-', lw=0.5, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax1)
ax1.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax1.set_xlabel('čas [s]', ha='left', va='top')
ax1.xaxis.set_label_coords(1.05, -0.07, transform=ax1.transAxes)
ax1.set_ylabel('Snímač 2 [V]', ha='right', va='bottom', rotation=90)
ax1.yaxis.set_label_coords(-0.07, 1.05, transform=ax1.transAxes)
ax1.set_ylim(3, 10)

# ===== Layout =====
fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3],
                    figPlotParam[4], figPlotParam[5])

# ===== Save =====
plt.savefig(os.path.join(figSaveDir, f"{figName}.png"))
plt.close()

# %%
# Obr. 5

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_prevodova_sensors6'

# load CSV
data_main = pd.read_csv('../dataRepo/ts_prevodova6.csv', header=None, skiprows=0).values
t  = data_main[:, 0]
y1 = data_main[:, 3]   
y2 = data_main[:, 4]   

# ===== Panel =====
figPlotParam = fcnDefaultFigSize(7.2, 0.17, 0.88, 0.12, 0.40, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])
subPlots = gridspec.GridSpec(2, 1, height_ratios=[1, 1])


fcn_setFigStyle_basicTimeSeries(fig, figPlotParam, ['Čas [s]', '', ''])

# --- Horný graf
ax0 = plt.subplot(subPlots[0])
ax0.plot(t, y1, '-', lw=0.5, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax0)
ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax0.set_xlabel('čas [s]', ha='left', va='top')
ax0.xaxis.set_label_coords(1.05, -0.07, transform=ax0.transAxes)
ax0.set_ylabel('Snímač 1 [V]', ha='right', va='bottom', rotation=90)
ax0.yaxis.set_label_coords(-0.07, 1.05, transform=ax0.transAxes)
ax0.set_ylim(3, 10)

# --- Dolný graf
ax1 = plt.subplot(subPlots[1])
ax1.plot(t, y2, '-', lw=0.5, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax1)
ax1.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax1.set_xlabel('čas [s]', ha='left', va='top')
ax1.xaxis.set_label_coords(1.05, -0.07, transform=ax1.transAxes)
ax1.set_ylabel('Snímač 2 [V]', ha='right', va='bottom', rotation=90)
ax1.yaxis.set_label_coords(-0.07, 1.05, transform=ax1.transAxes)
ax1.set_ylim(3, 10)

# ===== Layout =====
fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3],
                    figPlotParam[4], figPlotParam[5])

# ===== Save =====
plt.savefig(os.path.join(figSaveDir, f"{figName}.png"))
plt.close()

# %%
# Obr. 6

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_prevodova_sensors9'

# load CSV
data_main = pd.read_csv('../dataRepo/ts_prevodova9.csv', header=None, skiprows=0).values
t  = data_main[:, 0]
y1 = data_main[:, 3]   
y2 = data_main[:, 4]   

# ===== Panel =====
figPlotParam = fcnDefaultFigSize(7.2, 0.17, 0.88, 0.12, 0.40, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])
subPlots = gridspec.GridSpec(2, 1, height_ratios=[1, 1])


fcn_setFigStyle_basicTimeSeries(fig, figPlotParam, ['Čas [s]', '', ''])

# --- Horný graf
ax0 = plt.subplot(subPlots[0])
ax0.plot(t, y1, '-', lw=0.5, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax0)
ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax0.set_xlabel('čas [s]', ha='left', va='top')
ax0.xaxis.set_label_coords(1.05, -0.07, transform=ax0.transAxes)
ax0.set_ylabel('Snímač 1 [V]', ha='right', va='bottom', rotation=90)
ax0.yaxis.set_label_coords(-0.07, 1.05, transform=ax0.transAxes)
ax0.set_ylim(3, 10)

# --- Dolný graf
ax1 = plt.subplot(subPlots[1])
ax1.plot(t, y2, '-', lw=0.5, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax1)
ax1.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax1.set_xlabel('čas [s]', ha='left', va='top')
ax1.xaxis.set_label_coords(1.05, -0.07, transform=ax1.transAxes)
ax1.set_ylabel('Snímač 2 [V]', ha='right', va='bottom', rotation=90)
ax1.yaxis.set_label_coords(-0.07, 1.05, transform=ax1.transAxes)
ax1.set_ylim(3, 10)

# ===== Layout =====
fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3],
                    figPlotParam[4], figPlotParam[5])

# ===== Save =====
plt.savefig(os.path.join(figSaveDir, f"{figName}.png"))
plt.close()

# %%
# Obr. 7

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_static_sensors3'

# load CSV
data_main = pd.read_csv('../dataRepo/ts_static3.csv', header=None, skiprows=0).values
t  = data_main[:, 0]
y1 = data_main[:, 1]   
y2 = data_main[:, 2]   

# ===== Panel =====
figPlotParam = fcnDefaultFigSize(6.5, 0.17, 0.88, 0.12, 0.40, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])
subPlots = gridspec.GridSpec(2, 1, height_ratios=[1, 1])


fcn_setFigStyle_basicTimeSeries(fig, figPlotParam, ['Čas [s]', '', ''])

# --- Horný graf
ax0 = plt.subplot(subPlots[0])
ax0.plot(t, y1, 'o--', lw=0.3, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax0)
ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax0.set_xlabel('Vstup [V]', ha='left', va='top')
ax0.xaxis.set_label_coords(1.05, -0.07, transform=ax0.transAxes)
ax0.set_ylabel('Snímač 1 [V]', ha='right', va='bottom', rotation=90)
ax0.yaxis.set_label_coords(-0.07, 1.05, transform=ax0.transAxes)
ax0.set_ylim(3, 10)

# --- Dolný graf
ax1 = plt.subplot(subPlots[1])
ax1.plot(t, y2, 'o--', lw=0.3, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax1)
ax1.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax1.set_xlabel('Vstup [V]', ha='left', va='top')
ax1.xaxis.set_label_coords(1.05, -0.07, transform=ax1.transAxes)
ax1.set_ylabel('Snímač 2 [V]', ha='right', va='bottom', rotation=90)
ax1.yaxis.set_label_coords(-0.07, 1.05, transform=ax1.transAxes)
ax1.set_ylim(3, 10)

# ===== Layout =====
fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3],
                    figPlotParam[4], figPlotParam[5])

# ===== Save =====
plt.savefig(os.path.join(figSaveDir, f"{figName}.png"))
plt.close()

# %%
# Obr. 8

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_static_sensors6'

# load CSV
data_main = pd.read_csv('../dataRepo/ts_static6.csv', header=None, skiprows=0).values
t  = data_main[:, 0]
y1 = data_main[:, 1]   
y2 = data_main[:, 2]   

# ===== Panel =====
figPlotParam = fcnDefaultFigSize(6.5, 0.17, 0.88, 0.12, 0.40, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])
subPlots = gridspec.GridSpec(2, 1, height_ratios=[1, 1])


fcn_setFigStyle_basicTimeSeries(fig, figPlotParam, ['Čas [s]', '', ''])

# --- Horný graf
ax0 = plt.subplot(subPlots[0])
ax0.plot(t, y1, 'o--', lw=0.3, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax0)
ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax0.set_xlabel('Vstup [V]', ha='left', va='top')
ax0.xaxis.set_label_coords(1.05, -0.07, transform=ax0.transAxes)
ax0.set_ylabel('Snímač 1 [V]', ha='right', va='bottom', rotation=90)
ax0.yaxis.set_label_coords(-0.07, 1.05, transform=ax0.transAxes)
ax0.set_ylim(3, 10)

# --- Dolný graf
ax1 = plt.subplot(subPlots[1])
ax1.plot(t, y2, 'o--', lw=0.3, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax1)
ax1.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax1.set_xlabel('Vstup [V]', ha='left', va='top')
ax1.xaxis.set_label_coords(1.05, -0.07, transform=ax1.transAxes)
ax1.set_ylabel('Snímač 2 [V]', ha='right', va='bottom', rotation=90)
ax1.yaxis.set_label_coords(-0.07, 1.05, transform=ax1.transAxes)
ax1.set_ylim(3, 10)

# ===== Layout =====
fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3],
                    figPlotParam[4], figPlotParam[5])

# ===== Save =====
plt.savefig(os.path.join(figSaveDir, f"{figName}.png"))
plt.close()

# %%
# Obr. 9

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_static_sensors9'

# load CSV
data_main = pd.read_csv('../dataRepo/ts_static9.csv', header=None, skiprows=0).values
t  = data_main[:, 0]
y1 = data_main[:, 1]   
y2 = data_main[:, 2]   

# ===== Panel =====
figPlotParam = fcnDefaultFigSize(6.5, 0.17, 0.88, 0.12, 0.40, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])
subPlots = gridspec.GridSpec(2, 1, height_ratios=[1, 1])


fcn_setFigStyle_basicTimeSeries(fig, figPlotParam, ['Čas [s]', '', ''])

# --- Horný graf
ax0 = plt.subplot(subPlots[0])
ax0.plot(t, y1, 'o--', lw=0.3, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax0)
ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax0.set_xlabel('Vstup [V]', ha='left', va='top')
ax0.xaxis.set_label_coords(1.05, -0.07, transform=ax0.transAxes)
ax0.set_ylabel('Snímač 1 [V]', ha='right', va='bottom', rotation=90)
ax0.yaxis.set_label_coords(-0.07, 1.05, transform=ax0.transAxes)
ax0.set_ylim(3, 10)

# --- Dolný graf
ax1 = plt.subplot(subPlots[1])
ax1.plot(t, y2, 'o--', lw=0.3, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax1)
ax1.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax1.set_xlabel('Vstup [V]', ha='left', va='top')
ax1.xaxis.set_label_coords(1.05, -0.07, transform=ax1.transAxes)
ax1.set_ylabel('Snímač 2 [V]', ha='right', va='bottom', rotation=90)
ax1.yaxis.set_label_coords(-0.07, 1.05, transform=ax1.transAxes)
ax1.set_ylim(3, 10)

# ===== Layout =====
fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3],
                    figPlotParam[4], figPlotParam[5])

# ===== Save =====
plt.savefig(os.path.join(figSaveDir, f"{figName}.png"))
plt.close()

# %%
# Obr. 10

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_pb_vent6_spir4_ident_raw'

# load CSV
data_main = pd.read_csv('../dataRepo/ts_pb_vent6_spir4_raw.csv', header=None, skiprows=1).values
t  = data_main[:, 0]
y1 = data_main[:, 1]   
y2 = data_main[:, 2]   

# ===== Panel =====
figPlotParam = fcnDefaultFigSize(8, 0.17, 0.88, 0.12, 0.40, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])
subPlots = gridspec.GridSpec(2, 1, height_ratios=[1, 1])


fcn_setFigStyle_basicTimeSeries(fig, figPlotParam, ['Čas [s]', '', ''])

# --- Horný graf
ax0 = plt.subplot(subPlots[0])
ax0.plot(t, y1, '-', lw=0.5, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax0)
ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax0.set_xlabel('čas [s]', ha='left', va='top')
ax0.xaxis.set_label_coords(1.05, -0.07, transform=ax0.transAxes)
ax0.set_ylabel('Špirála [V]', ha='right', va='bottom', rotation=90)
ax0.yaxis.set_label_coords(-0.07, 1.05, transform=ax0.transAxes)
ax0.set_ylim(3, 5)

# --- Dolný graf
ax1 = plt.subplot(subPlots[1])
ax1.plot(t, y2, '-', lw=0.5, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax1)
ax1.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax1.set_xlabel('čas [s]', ha='left', va='top')
ax1.xaxis.set_label_coords(1.05, -0.07, transform=ax1.transAxes)
ax1.set_ylabel('Snímač 1 [V]', ha='right', va='bottom', rotation=90)
ax1.yaxis.set_label_coords(-0.07, 1.05, transform=ax1.transAxes)
ax1.set_ylim(6, 7.5)

# ===== Layout =====
fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3],
                    figPlotParam[4], figPlotParam[5])

# ===== Save =====
plt.savefig(os.path.join(figSaveDir, f"{figName}.png"))
plt.close()

# %%
# Obr. 11

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_pb_vent6_spir4_ident_raw_normalized'

# load CSV
data_main = pd.read_csv('../dataRepo/ts_pb_vent6_spir4_raw.csv', header=None, skiprows=1).values
t  = data_main[:, 0]
y1 = data_main[:, 3]   
y2 = data_main[:, 4]   

# ===== Panel =====
figPlotParam = fcnDefaultFigSize(10, 0.17, 0.88, 0.12, 0.40, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])
subPlots = gridspec.GridSpec(2, 1, height_ratios=[1, 1])


fcn_setFigStyle_basicTimeSeries(fig, figPlotParam, ['Čas [s]', '', ''])

# --- Horný graf
ax0 = plt.subplot(subPlots[0])
ax0.plot(t, y1, '-', lw=0.5, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax0)
ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax0.set_xlabel('čas [s]', ha='left', va='top')
ax0.xaxis.set_label_coords(1.05, -0.07, transform=ax0.transAxes)
ax0.set_ylabel('Špirála [V]', ha='right', va='bottom', rotation=90)
ax0.yaxis.set_label_coords(-0.07, 1.05, transform=ax0.transAxes)
ax0.set_ylim(-0.6, 0.6)

# --- Dolný graf
ax1 = plt.subplot(subPlots[1])
ax1.plot(t, y2, '-', lw=0.5, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax1)
ax1.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax1.set_xlabel('čas [s]', ha='left', va='top')
ax1.xaxis.set_label_coords(1.05, -0.07, transform=ax1.transAxes)
ax1.set_ylabel('Snímač 1 [V]', ha='right', va='bottom', rotation=90)
ax1.yaxis.set_label_coords(-0.07, 1.05, transform=ax1.transAxes)
ax1.set_ylim(-0.7, 0.7)

# ===== Layout =====
fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3],
                    figPlotParam[4], figPlotParam[5])

# ===== Save =====
plt.savefig(os.path.join(figSaveDir, f"{figName}.png"))
plt.close()

# %%
# Obr. 12

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_pb_vent6_spir4_ident_avg'

# load CSV
data_main = pd.read_csv('../dataRepo/ts_pb_vent6_spir4_avg.csv', header=None, skiprows=1).values
t  = data_main[:, 0]
y1 = data_main[:, 1]   
y2 = data_main[:, 2]   

# ===== Panel =====
figPlotParam = fcnDefaultFigSize(7, 0.17, 0.88, 0.12, 0.40, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])
subPlots = gridspec.GridSpec(2, 1, height_ratios=[1, 1])


fcn_setFigStyle_basicTimeSeries(fig, figPlotParam, ['Čas [s]', '', ''])

# --- Horný graf
ax0 = plt.subplot(subPlots[0])
ax0.plot(t, y1, '-', lw=0.5, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax0)
ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax0.set_xlabel('čas [s]', ha='left', va='top')
ax0.xaxis.set_label_coords(1.05, -0.07, transform=ax0.transAxes)
ax0.set_ylabel('Špirála [V]', ha='right', va='bottom', rotation=90)
ax0.yaxis.set_label_coords(-0.07, 1.05, transform=ax0.transAxes)
ax0.set_ylim(-0.6, 0.6)

# --- Dolný graf
ax1 = plt.subplot(subPlots[1])
ax1.plot(t, y2, '-', lw=0.5, ms = 2, color='k', drawstyle='default')
fcnDefaultAxisStyle(ax1)
ax1.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax1.set_xlabel('čas [s]', ha='left', va='top')
ax1.xaxis.set_label_coords(1.05, -0.07, transform=ax1.transAxes)
ax1.set_ylabel('Snímač 1 [V]', ha='right', va='bottom', rotation=90)
ax1.yaxis.set_label_coords(-0.07, 1.05, transform=ax1.transAxes)
ax1.set_ylim(-0.7, 0.7)

# ===== Layout =====
fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3],
                    figPlotParam[4], figPlotParam[5])

# ===== Save =====
plt.savefig(os.path.join(figSaveDir, f"{figName}.png"))
plt.close()

# %%
# Obr. 13

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_pb_vent6_spir4_ident_comparison'

# ===== Load CSV =====
data_main = pd.read_csv(
    '../dataRepo/ts_pb_vent6_spir4_id.csv',
    header=None,
    skiprows=1  # skip first line
).values

# ===== Panel =====
figPlotParam = fcnDefaultFigSize(6, 0.17, 0.88, 0.12, 0.4, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])
subPlots = gridspec.GridSpec(1, 1)
ax0 = plt.subplot(subPlots[0])

# ===== Plot =====
ax0.plot(data_main[:, 0], data_main[:, 2], '-', lw=0.6, color='k', label='Snímač 1 – meraná')
ax0.plot(data_main[:, 0], data_main[:, 3], '--', lw=0.8, color='tab:blue',
         label='Snímač 1 – metóda najmenších štvorcov')
ax0.plot(data_main[:, 0], data_main[:, 4], '--', lw=0.8, color='tab:red',
         label='Snímač 1 – metóda fminsearch')

# ===== Style =====
fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3],
                    figPlotParam[4], figPlotParam[5])
fcn_setFigStyle_basicTimeSeries(
    fig, figPlotParam, ['čas [s]', 'Snímač 1 [V]', ''])
ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax0.legend(frameon=False, fontsize=8, loc='best')

plt.savefig(os.path.join(figSaveDir, f"{figName}.png"), dpi=600)
plt.close()

# %%
# Obr. 14

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_pb_vent6_spir4_ident_approximated_comparison'

# ===== Load CSV =====
data_main = pd.read_csv(
    '../dataRepo/ts_pb_vent6_spir4_id_apprx.csv',
    header=None,
    skiprows=1  # skip first line
).values

# ===== Panel =====
figPlotParam = fcnDefaultFigSize(6, 0.17, 0.88, 0.12, 0.4, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])
subPlots = gridspec.GridSpec(1, 1)
ax0 = plt.subplot(subPlots[0])

# ===== Plot =====
ax0.plot(data_main[:, 0], data_main[:, 2], '-', lw=0.6, color='k', label='Snímač 1 – meraná')
ax0.plot(data_main[:, 0], data_main[:, 3], '--', lw=0.8, color='tab:blue',
         label='Snímač 1 – metóda najmenších štvorcov')
ax0.plot(data_main[:, 0], data_main[:, 4], '--', lw=0.8, color='tab:red',
         label='Snímač 1 – metóda fminsearch')

# ===== Style =====
fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3],
                    figPlotParam[4], figPlotParam[5])
fcn_setFigStyle_basicTimeSeries(
    fig, figPlotParam, ['čas [s]', 'Snímač 1 [V]', ''])
ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax0.legend(frameon=False, fontsize=8, loc='best')

plt.savefig(os.path.join(figSaveDir, f"{figName}.png"), dpi=600)
plt.close()

# %%
# Obr. 16

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_pb_vent6_spir4_pidtune_sim'

# load CSV
data_main = pd.read_csv('../dataRepo/ts_pb_vent6_spir4_pidtune_sim.csv', header=None, skiprows=1).values
t  = data_main[:, 0]
ref = data_main[:, 1]
u = data_main[:, 2]      
y = data_main[:, 3]     

# ===== Panel =====
figPlotParam = fcnDefaultFigSize(9.5, 0.17, 0.88, 0.12, 0.40, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])
subPlots = gridspec.GridSpec(2, 1, height_ratios=[1, 1])

fcn_setFigStyle_basicTimeSeries(fig, figPlotParam, ['čas [s]', '', ''])

# --- Upper plot
ax0 = plt.subplot(subPlots[0])

# black solid line
ax0.plot(t, y, '-', lw=0.6, color='k', label='Výstup')

# red dashed line
ax0.plot(t, ref, '--', lw=0.9, color='red', label='Referenčná krivka')

fcnDefaultAxisStyle(ax0)
ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')

ax0.set_xlabel('čas [s]', ha='left', va='top')
ax0.xaxis.set_label_coords(1.05, -0.07, transform=ax0.transAxes)

ax0.set_ylabel('Výstup [V]', ha='right', va='bottom', rotation=90)
ax0.yaxis.set_label_coords(-0.07, 1.05, transform=ax0.transAxes)

ax0.set_ylim(-0.1, 0.6)
ax0.legend(loc='upper right', fontsize=9)

# --- Lower plot
ax1 = plt.subplot(subPlots[1])

ax1.plot(t, u, '-', lw=0.6, color='k', label='Vstup – akčný zásah')

fcnDefaultAxisStyle(ax1)
ax1.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')

ax1.set_xlabel('čas [s]', ha='left', va='top')
ax1.xaxis.set_label_coords(1.05, -0.07, transform=ax1.transAxes)

ax1.set_ylabel('Vstup [V]', ha='right', va='bottom', rotation=90)
ax1.yaxis.set_label_coords(-0.07, 1.05, transform=ax1.transAxes)

ax1.set_ylim(-0.5, 2.5)

# ===== Layout =====
fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3],
                    figPlotParam[4], figPlotParam[5])

# ===== Save =====
plt.savefig(os.path.join(figSaveDir, f"{figName}.png"), dpi=300)
plt.close()

# %%
# Obr. 18

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_pb_vent6_spir4_PI_real'

# load CSV
data_main = pd.read_csv('../dataRepo/ts_pb_vent6_spir4_PI_real.csv', header=None, skiprows=1).values  

t  = data_main[:, 0]
ref = data_main[:, 3]
u = data_main[:, 1]      
y = data_main[:, 2]     

# ===== Panel =====
figPlotParam = fcnDefaultFigSize(9.5, 0.17, 0.88, 0.12, 0.40, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])
subPlots = gridspec.GridSpec(2, 1, height_ratios=[1, 1])

fcn_setFigStyle_basicTimeSeries(fig, figPlotParam, ['čas [s]', '', ''])

# --- Upper plot
ax0 = plt.subplot(subPlots[0])

# black solid line
ax0.plot(t, y, '-', lw=0.6, color='k', label='Výstup')

# red dashed line
ax0.plot(t, ref, '--', lw=0.9, color='red', label='Referenčná krivka')

fcnDefaultAxisStyle(ax0)
ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')

ax0.set_xlabel('čas [s]', ha='left', va='top')
ax0.xaxis.set_label_coords(1.05, -0.07, transform=ax0.transAxes)

ax0.set_ylabel('Výstup [V]', ha='right', va='bottom', rotation=90)
ax0.yaxis.set_label_coords(-0.07, 1.05, transform=ax0.transAxes)

ax0.set_ylim(-0.1, 0.6)
ax0.legend(loc='upper right', fontsize=9)

# --- Lower plot
ax1 = plt.subplot(subPlots[1])

ax1.plot(t, u, '-', lw=0.6, color='k', label='Vstup – akčný zásah')

fcnDefaultAxisStyle(ax1)
ax1.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')

ax1.set_xlabel('čas [s]', ha='left', va='top')
ax1.xaxis.set_label_coords(1.05, -0.07, transform=ax1.transAxes)

ax1.set_ylabel('Vstup [V]', ha='right', va='bottom', rotation=90)
ax1.yaxis.set_label_coords(-0.07, 1.05, transform=ax1.transAxes)

ax1.set_ylim(-0.5, 2.5)

# ===== Layout =====
fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3],
                    figPlotParam[4], figPlotParam[5])

# ===== Save =====
plt.savefig(os.path.join(figSaveDir, f"{figName}.png"), dpi=300)
plt.close()

# %%
# Obr. 19

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_pb_vent6_pbTopb_real_badToShow'

# load CSV
data_main = pd.read_csv('../dataRepo/ts_pb_vent6_pbTopb_real_badToShow.csv', header=None, skiprows=1).values  

t  = data_main[:, 0]
ref = data_main[:, 3]
u = data_main[:, 1]      
y = data_main[:, 2]     

# ===== Panel =====
figPlotParam = fcnDefaultFigSize(9.5, 0.17, 0.88, 0.12, 0.40, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])
subPlots = gridspec.GridSpec(2, 1, height_ratios=[1, 1])

fcn_setFigStyle_basicTimeSeries(fig, figPlotParam, ['čas [s]', '', ''])

# --- Upper plot
ax0 = plt.subplot(subPlots[0])

# black solid line
ax0.plot(t, y, '-', lw=0.6, color='k', label='Výstup')

# red dashed line
ax0.plot(t, ref, '--', lw=0.9, color='red', label='Referenčná krivka')

fcnDefaultAxisStyle(ax0)
ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')

ax0.set_xlabel('čas [s]', ha='left', va='top')
ax0.xaxis.set_label_coords(1.05, -0.07, transform=ax0.transAxes)

ax0.set_ylabel('Výstup [V]', ha='right', va='bottom', rotation=90)
ax0.yaxis.set_label_coords(-0.07, 1.05, transform=ax0.transAxes)

ax0.set_ylim(6.3, 7.9)
ax0.legend(loc='upper right', fontsize=9)

# --- Lower plot
ax1 = plt.subplot(subPlots[1])

ax1.plot(t, u, '-', lw=0.6, color='k', label='Vstup – akčný zásah')

fcnDefaultAxisStyle(ax1)
ax1.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')

ax1.set_xlabel('čas [s]', ha='left', va='top')
ax1.xaxis.set_label_coords(1.05, -0.07, transform=ax1.transAxes)

ax1.set_ylabel('Vstup [V]', ha='right', va='bottom', rotation=90)
ax1.yaxis.set_label_coords(-0.07, 1.05, transform=ax1.transAxes)

ax1.set_ylim(3, 10.2)

# ===== Layout =====
fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3],
                    figPlotParam[4], figPlotParam[5])

# ===== Save =====
plt.savefig(os.path.join(figSaveDir, f"{figName}.png"), dpi=300)
plt.close()

# %%
# Obr. 22

import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from figFcns_TeX import *

# ===== Params =====
figSaveDir = '../fig'
os.makedirs(figSaveDir, exist_ok=True)

figName = 'ts_ml_switch_1st'

# ===== Load CSV =====
data_main = pd.read_csv(
    '../dataRepo/ts_ml_switch_1st.csv',
    header=None,
    skiprows=1
).values

# ===== Panel =====
figPlotParam = fcnDefaultFigSize(20, 0.17, 0.88, 0.12, 0.4, 13)
fig = plt.figure(0, figsize=figPlotParam[0:2])

subPlots = gridspec.GridSpec(3, 1)

ax0 = plt.subplot(subPlots[0])
ax1 = plt.subplot(subPlots[1])
ax2 = plt.subplot(subPlots[2])

# ===== Subplot 1 (2 curves) =====
ax0.plot(data_main[:, 0], data_main[:, 1], '-', lw=0.6, color='k',
         label='y')
ax0.plot(data_main[:, 0], data_main[:, 2], '--', lw=0.8, color='tab:red',
         label='w')

ax0.set_xlabel('čas [s]', ha='left', va='top')
ax0.xaxis.set_label_coords(1.05, -0.07, transform=ax0.transAxes)

ax0.set_ylabel('Snímač 1 [V]', ha='right', va='bottom', rotation=90)
ax0.yaxis.set_label_coords(-0.07, 1.05, transform=ax0.transAxes)

ax0.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax0.legend(frameon=False, fontsize=8, loc='upper right', bbox_to_anchor=(1.1, 1.0))


# ===== Subplot 2 (2 curves) =====
ax1.plot(data_main[:, 0], data_main[:, 3], '-', lw=0.3, color='tab:orange',
         label='u - globálny')
ax1.plot(data_main[:, 0], data_main[:, 4], '--', lw=0.3, color='tab:blue',
         label='u - lokálny')

ax1.set_xlabel('čas [s]', ha='left', va='top')
ax1.xaxis.set_label_coords(1.05, -0.07, transform=ax1.transAxes)

ax1.set_ylabel('Akčný zásah [V]', ha='right', va='bottom', rotation=90)
ax1.yaxis.set_label_coords(-0.07, 1.05, transform=ax1.transAxes)

ax1.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax1.legend(frameon=False, fontsize=8, loc='upper right', bbox_to_anchor=(1.2, 1.0))


# ===== Subplot 3 (3 curves) =====
ax2.plot(data_main[:, 0], data_main[:, 6], '-', lw=0.8, color='tab:red',
         label='w - globálny')
ax2.plot(data_main[:, 0], data_main[:, 7], '--', lw=0.8, color='tab:orange',
         label='w - globálny \n zmiernený')
ax2.plot(data_main[:, 0], data_main[:, 8], '-', lw=0.8, color='tab:blue',
         label='w - lokálny')

ax2.set_xlabel('čas [s]', ha='left', va='top')
ax2.xaxis.set_label_coords(1.05, -0.07, transform=ax2.transAxes)

ax2.set_ylabel('Požadovaná hodnota [V]', ha='right', va='bottom', rotation=90)
ax2.yaxis.set_label_coords(-0.07, 1.05, transform=ax2.transAxes)

ax2.grid(True, which='both', linestyle='--', linewidth=0.1, color='k')
ax2.legend(frameon=False, fontsize=8, loc='upper right', bbox_to_anchor=(1.2, 1.0))

# ===== Style =====
fcnDefaultLayoutAdj(fig, figPlotParam[2], figPlotParam[3],
                    figPlotParam[4], figPlotParam[5])


plt.savefig(os.path.join(figSaveDir, f"{figName}.png"), dpi=600)
plt.close()
